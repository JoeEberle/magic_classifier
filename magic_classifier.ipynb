# %% [markdown]
# ![magic_classifier.png](attachment:7dc3038e-52ef-4235-ba11-039782f4fbe0.png)

# %% [markdown]
# # 🧩 AI Magic Commands
#
# ##  AI magic to empower and enrich humans
#
# > Created by **ThriveAI  ...      Joe Eberle, Kyle Rooot Al Seoud, Frank Metty, Pat Coyle**
# > 🗓️ Started: April 18, 2025
# > 📫 Contact: [josepheberle@outlook.com](mailto:josepheberle@outlook.com)
# > 🔗 GitHub: [JoeEberle](https://github.com/JoeEberle/)

# %%
import os
import schedule
from datetime import datetime
import pandas as pd 
import magic as mg
import domain_topic_classifier as dtc
import quick_logger as ql
import talking_code as tc 
import file_manager as fm 
import PIL.Image
import story_board as sb 
import time
from IPython.display import Markdown, display, Image
from wordcloud import WordCloud, STOPWORDS
stopwords = STOPWORDS
print(f"Libraries Imported succesfully on {datetime.now().date()} at {datetime.now().time()}")
# Out:
# {'topic': 'medication', 'domain': 'healthcare', 'association_strength': 'weak', 'confidence': (100.0, 50.0), 'evidence': {'domain': 'heart, aspirin', 'topic': 'aspirin'}, 'explanation': "Topic 'medication' is typically under domain 'health_care', not 'healthcare'."}
# Libraries Imported succesfully on 2025-07-26 at 22:31:09.160195

# %% [markdown]
# ## Optional Step 0 - Intitiate Configuration Settings and name the overall solution

# %%
import configparser 
config = configparser.ConfigParser()
from wordcloud import WordCloud, STOPWORDS
cfg = config.read('config.ini')  

solution_name = 'magic_classifier'

# %%
definition ='''
# 🧩 AI Magic Commands

#### AI magic to empower and enrich humans 

> Created by **ThriveAI  ...      Joe Eberle**  
> 🗓️ Started: April 18, 2025 
> 📫 Contact: [josepheberle@outlook.com](mailto:josepheberle@outlook.com)  
> 🔗 GitHub: [JoeEberle](https://github.com/JoeEberle/)

'''

sb.outmd(definition)
# Out:
# # 🧩 AI Magic Commands
#
# #### AI magic to empower and enrich humans
#
# > Created by **ThriveAI  ...      Joe Eberle**
# > 🗓️ Started: April 18, 2025
# > 📫 Contact: [josepheberle@outlook.com](mailto:josepheberle@outlook.com)
# > 🔗 GitHub: [JoeEberle](https://github.com/JoeEberle/)

# %% [markdown]
# ## Optional Step 0 - Intitiate Logging and debugging

# %%
# Establish the Python Logger  
import logging # built in python library that does not need to be installed 
import quick_logger as ql

global start_stime 
start_time = ql.set_start_time()
logging = ql.create_logger_start(solution_name, start_time) 
ql.set_speaking_log(False)
ql.set_speaking_steps(False)
ql.pvlog('info',f'Process {solution_name} Step 0 - Initializing and starting Logging Process.')
# Out:
# Process magic_classifier Step 0 - Initializing and starting Logging Process.

# %%
definition ='''
# 🧠 Magic Commands

Thrive AI supports the following intelligent functions to assist with data exploration, analytics, and service navigation:

### 🔥 `correlation heatmap`
Generate a visual heatmap showing the correlation between variables in your dataset.

### ☁️ `word cloud`
Create a word cloud from text data to highlight frequently occurring terms.

### 📊 `descriptive statistics`
Compute basic summary statistics like mean, median, standard deviation, and more.

### 📈 `epidemiology`
Run population-level analytics for disease prevalence, incidence, or risk factor profiling.

### 📉 `principal component analysis`
Perform PCA to reduce dimensionality and identify dominant patterns in your data.

### 🧹 `feature reduction`
Apply statistical techniques to remove redundant or irrelevant features.

### 🗂️ `data catalogue`
Automatically generate metadata and schema documentation for your dataset.

### 📊 `visual dashboard`
Create interactive dashboards for data visualization using tools like Plotly or Streamlit.

### 🔄 `warehouse transformation`
Execute data transformation scripts on your enterprise data warehouse.

### 👥 `employee enrichment`
Integrate internal HR or staff data for population health workforce analysis.

### 🧠 `mind map`
Generate conceptual visual maps to represent topic relationships and themes.

### 🧬 `ontology`
Link your data to a healthcare or social determinants ontology for semantic enrichment.

### 🔍 `data science`
Run data science workflows like clustering, regression, or classification on selected data.

### 🚭 `smoking cessation`
Identify populations at risk and analyze outcomes related to tobacco cessation programs.

### 🧪 `diabetes risk analysis`
Evaluate individual or population-level risk for developing diabetes based on key indicators.

### 👨‍⚕️ `Find a provider PCP`
Locate a primary care provider based on geography, specialty, and insurance.

### 🧑‍⚕️ `Find a provider Specialist`
Identify a specialist provider based on patient needs and location.

### 🏘️ `Find a social needs`
Connect users with community-based organizations addressing social needs (e.g., food, housing, transportation).

'''

sb.start_story(definition)
# Out:
# # 🧠 Magic Commands
#
# Thrive AI supports the following intelligent functions to assist with data exploration, analytics, and service navigation:
#
# ### 🔥 `correlation heatmap`
# Generate a visual heatmap showing the correlation between variables in your dataset.
#
# ### ☁️ `word cloud`
# Create a word cloud from text data to highlight frequently occurring terms.
#
# ### 📊 `descriptive statistics`
# Compute basic summary statistics like mean, median, standard deviation, and more.
#
# ### 📈 `epidemiology`
# Run population-level analytics for disease prevalence, incidence, or risk factor profiling.
#
# ### 📉 `principal component analysis`
# Perform PCA to reduce dimensionality and identify dominant patterns in your data.
#
# ### 🧹 `feature reduction`
# Apply statistical techniques to remove redundant or irrelevant features.
#
# ### 🗂️ `data catalogue`
# Automatically generate metadata and schema documentation for your dataset.
#
# ### 📊 `visual dashboard`
# Create interactive dashboards for data visualization using tools like Plotly or Streamlit.
#
# ### 🔄 `warehouse transformation`
# Execute data transformation scripts on your enterprise data warehouse.
#
# ### 👥 `employee enrichment`
# Integrate internal HR or staff data for population health workforce analysis.
#
# ### 🧠 `mind map`
# Generate conceptual visual maps to represent topic relationships and themes.
#
# ### 🧬 `ontology`
# Link your data to a healthcare or social determinants ontology for semantic enrichment.
#
# ### 🔍 `data science`
# Run data science workflows like clustering, regression, or classification on selected data.
#
# ### 🚭 `smoking cessation`
# Identify populations at risk and analyze outcomes related to tobacco cessation programs.
#
# ### 🧪 `diabetes risk analysis`
# Evaluate individual or population-level risk for developing diabetes based on key indicators.
#
# ### 👨‍⚕️ `Find a provider PCP`
# Locate a primary care provider based on geography, specialty, and insurance.
#
# ### 🧑‍⚕️ `Find a provider Specialist`
# Identify a specialist provider based on patient needs and location.
#
# ### 🏘️ `Find a social needs`
# Connect users with community-based organizations addressing social needs (e.g., food, housing, transportation).

# %%
help(mg)
# Out:
# Help on module magic:
#
# NAME
#     magic
#
# FUNCTIONS
#     classify_text(text, keywords_dict, use_fuzzy=False, use_stemming=False)
#         # Core classification function
#
#     find_magic_table_name(domain)
#
#     get_sample_questions()
#
#     heatmap_insights_generator(df, threshold=0.7, max_pairs=10)
#         Generate Markdown summary of strongest correlations in a dataframe.
#
#         Parameters:
#         df (DataFrame): Input pandas dataframe
#         threshold (float): Correlation threshold to report
#         max_pairs (int): Maximum number of pairs to report
#
#         Returns:
#         str: Markdown formatted summary
#
#     load_keywords(file_path)
#         # Load and prepare keyword lists
#
#     magic_classifier(text, use_fuzzy=False, use_stemming=False)
#
#     magic_data_load(table_name)
#
#     perform_magic(magic_command, table_name)
#
#     perform_magic_correlation_heatmap(df)
#
#     perform_magic_histogram(df)
#
#     perform_magic_pairplot(df, hue_value)
#
#     perform_magic_word_cloud(df, shape_image_file)
#
#     preprocess_text(text, use_stemming=False)
#
#     run_magic(sentence)
#
#     run_magic_sample_test()
#
#     test_magic_classifier(sample_sentence)
#
# DATA
#     MAGIC_KEYWORDS = {'correlation heatmap': {r'\correlation heatmap', 'co...
#     STOPWORDS = {'a', 'about', 'above', 'after', 'again', 'against', ...}
#     stemmer = <PorterStemmer>
#     stopwords = {'a', 'about', 'above', 'after', 'again', 'against', ...}
#
# FILE
#     c:\users\josep\magic_classifier\magic.py

# %%
import postgres_utils as pg
help(pg)
# Out:
# Help on module postgres_utils:
#
# NAME
#     postgres_utils
#
# FUNCTIONS
#     check_connection(conn)
#         Checks if the database connection is alive.
#         Returns True if the connection is valid, otherwise False.
#
#     connect_to_postgresql(DB_NAME, USER, PASSWORD, HOST, PORT)
#         Establishes a connection to a PostgreSQL database using psycopg.
#         Returns the connection object if successful, otherwise None.
#
#     create_pretend_employee_df()
#
#     create_table_from_dataframe(df, table_name, dbname, user, password, host, port)
#         Creates a PostgreSQL table based on the DataFrame structure and inserts all rows.
#
#         Parameters:
#             df (pd.DataFrame): The DataFrame whose structure and data will be used.
#             table_name (str): The name of the PostgreSQL table to create.
#             dbname (str): Database name.
#             user (str): Database username.
#             password (str): Database password.
#             host (str, optional): Database host. Defaults to "localhost".
#             port (str, optional): Database port. Defaults to "5432".
#
#         Returns:
#             bool: True if successful, False otherwise.
#
#     drop_table(conn, table_name)
#         Drops a table from the connected PostgreSQL database.
#
#         Parameters:
#             conn: The active database connection.
#             table_name (str): The name of the table to drop.
#
#         Returns:
#             bool: True if the table was dropped successfully, False otherwise.
#
#     get_connection_credentials(DB_NAME='postgres', USER='postgres', PASSWORD='admin', HOST='localhost', PORT='5432')
#         Returns credentials for database connection.
#
#     infer_sql_dtype(pd_dtype)
#         Maps pandas dtypes to PostgreSQL data types.
#
#         Parameters:
#             pd_dtype (dtype): A pandas data type.
#
#         Returns:
#             str: Corresponding PostgreSQL data type.
#
#     query_to_dataframe(query, conn)
#         Executes a given SQL SELECT query using an existing connection and returns the results as a pandas DataFrame.
#
#         Parameters:
#             query (str): The SQL SELECT statement to execute.
#             conn (psycopg.Connection): An active psycopg database connection.
#
#         Returns:
#             pd.DataFrame: A DataFrame containing the query results.
#
#     select_query(conn, sql_query='SELECT version();')
#         Runs a simple SELECT statement to verify the database connection.
#         Returns True if the query executes successfully.
#
#     sql_to_dataframe(query, dbname, user, password, host, port)
#         Executes a given SQL SELECT query and retrieves the results into a pandas DataFrame.
#
#         Parameters:
#             query (str): The SQL SELECT statement to execute.
#             dbname (str): Database name.
#             user (str): Database username.
#             password (str): Database password.
#             host (str, optional): Database host.
#             port (str, optional): Database port.
#
#         Returns:
#             pd.DataFrame: A DataFrame containing the query results.
#
#     test_potgresql_workflow()
#
#     verify_query(conn, sql_query='SELECT version();')
#         Runs a simple SELECT statement to verify the database connection.
#         Returns True if the query executes successfully.
#
# DATA
#     __warningregistry__ = {'version': 11385, ('pandas only supports SQLAlc...
#
# FILE
#     c:\users\josep\magic_classifier\postgres_utils.py

# %%
test_sentences = mg.get_sample_questions()

# %%
for idx, sentence in enumerate(test_sentences):
    print(f"#{idx} {sentence} ")
# Out:
# #0 What is the epidemology of breast cancer
# #1 Risk stratify the patients most likely to hospitalize in 30 days
# #2 Provide the list of tables related to patients
# #3 Provide a mind map regarding the etiology of cancer
# #4 Provide descriptive statistics on the provider table
# #5 Provide a dashboard about smokers
# #6 provide data scientifically engineered for knowledge expansion
# #7 Can the platform make recommendations on how to make warehouse more efficient

# %%
help(dtc)
# Out:
# Help on module domain_topic_classifier:
#
# NAME
#     domain_topic_classifier
#
# FUNCTIONS
#     classify_text(text, keywords_dict, use_fuzzy=False, use_stemming=False)
#         # Core classification function
#
#     compute_domain_topic_association(text, use_fuzzy=False, use_stemming=False)
#
#     domain_classifier(text, use_fuzzy=False, use_stemming=False)
#
#     get_sample_questions()
#
#     hostility_classifier(text, use_fuzzy=False, use_stemming=False)
#
#     innapropriate_language_classifier(text, use_fuzzy=False, use_stemming=False)
#
#     load_keywords(file_path)
#         # Load and prepare keyword lists
#
#     phi_classifier(text, use_fuzzy=False, use_stemming=False)
#
#     practicing_medicine_classifier(text, use_fuzzy=False, use_stemming=False)
#
#     preprocess_text(text, use_stemming=False)
#
#     racism_classifier(text, use_fuzzy=False, use_stemming=False)
#
#     run_domain_topic_sample_test()
#
#     run_ethical_guardrail_sample_test()
#
#     sexism_classifier(text, use_fuzzy=False, use_stemming=False)
#
#     test_domain_topic_classifier(sample_sentence)
#
#     test_ethical_guardrail_classifier(sample_sentence)
#
#     topic_classifier(text, use_fuzzy=False, use_stemming=False)
#
# DATA
#     DOMAIN_KEYWORDS = {'healthcare': {'ADHD', 'TIA', 'a1c', 'ablation', 'a...
#     HOSTILITY_KEYWORDS = {'aggressive': {'abuse', 'angry', 'curse', 'furio...
#     INNAPROPRIATE_KEYWORDS = {'innapropriatelanguage': {'abuse', 'angry', ...
#     PHI_KEYWORDS = {'phi': {'address', 'date of birth', 'email address', '...
#     PRACTICING_MEDICINE_KEYWORDS = {'practicing_medicine': {'am I sick', '...
#     RACISM_KEYWORDS = {'antisemitic': {'anti-zionist not antisemitic', 'di...
#     SEXISM_KEYWORDS = {'gender slurs': {'bitch', 'cunt', 'dyke', 'feminazi...
#     TOPIC_KEYWORDS = {'anatomy': {'arm', 'artery', 'bladder', 'bone', 'bra...
#     TOPIC_TO_DOMAIN = {'anatomy': 'health_care', 'behavioral': 'health_car...
#     result = {'association_strength': 'weak', 'confidence': (100.0, 50.0),...
#     stemmer = <PorterStemmer>
#
# FILE
#     c:\users\josep\magic_classifier\domain_topic_classifier.py

# %%
for idx, sentence in enumerate(test_sentences):
    domain_class,domain_score,domain_confidence,domain_evidence = dtc.domain_classifier(sentence, True, True)
    magic_class,magic_score,magic_confidence,magic_evidence = mg.magic_classifier(sentence, True, True)
    magic_table = mg.find_magic_table_name(domain_class)  
    print(f"\n#{idx}  {sentence} \n\nmagic class:{magic_class}  in domain:{domain_class}  finding table:{magic_table} \n\n")
# Out:
# #0  What is the epidemology of breast cancer
#
# magic class:epidemiology  in domain:healthcare  finding table:wny_health
#
#
#
# #1  Risk stratify the patients most likely to hospitalize in 30 days
#
# magic class:risk stratify  in domain:healthcare  finding table:wny_health
#
#
#
# #2  Provide the list of tables related to patients
#
# magic class:data catalog  in domain:healthcare  finding table:wny_health
#
#
#
# #3  Provide a mind map regarding the etiology of cancer
#
# magic class:mind map  in domain:healthcare  finding table:wny_health
#
#
#
# #4  Provide descriptive statistics on the provider table
#
# magic class:descriptive statistics  in domain:general  finding table:wny_health
#
#
#
# #5  Provide a dashboard about smokers
#
# magic class:visual dashboard  in domain:healthcare  finding table:wny_health
#
#
#
# #6  provide data scientifically engineered for knowledge expansion
#
# magic class:general  in domain:general  finding table:wny_health
#
#
#
# #7  Can the platform make recommendations on how to make warehouse more efficient
#
# magic class:warehouse transformation  in domain:titanic  finding table:titanic

# %%
graph = mg.run_magic( "perform correlation heatmap on titanic disaster" )
# Out:
# ✅ Connection to PostgreSQL successful!
# C:\Users\josep\magic_classifier\postgres_utils.py:222: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# ✅ Query executed successfully. Data retrieved.

# %%
graph = mg.run_magic( "perform word cloud on penguins" )
# Out:
# ✅ Connection to PostgreSQL successful!
# ✅ Query executed successfully. Data retrieved.
# C:\Users\josep\magic_classifier\postgres_utils.py:222: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
graph = mg.run_magic( "Id like a wordcloud for WNY health" )
# Out:
# ✅ Connection to PostgreSQL successful!
# ✅ Query executed successfully. Data retrieved.
# C:\Users\josep\magic_classifier\postgres_utils.py:222: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
graph = mg.run_magic( "can you create a pairplot for penguins" )
# Out:
# ✅ Connection to PostgreSQL successful!
# ✅ Query executed successfully. Data retrieved.
# C:\Users\josep\magic_classifier\postgres_utils.py:222: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
graph = mg.run_magic( "can you create a pairplot for penguins" )

# %%
sentence = "perform correlation heatmap on titanic disaster" 
domain_class,domain_score,domain_confidence,domain_evidence = dtc.domain_classifier(sentence, True, True)
magic_class,magic_score,magic_confidence,magic_evidence = mg.magic_classifier(sentence, True, True)
magic_table = mg.find_magic_table_name(domain_class)  
print(f"\n#{idx}  {sentence} \n\nmagic class:{magic_class}  in domain:{domain_class}  finding table:{magic_table} \n\n")  
graph = mg.perform_magic(magic_class, magic_table)
# Out:
# #7  perform correlation heatmap on titanic disaster
#
# magic class:correlation heatmap  in domain:titanic  finding table:titanic
#
#
# ✅ Connection to PostgreSQL successful!
# ✅ Query executed successfully. Data retrieved.
# C:\Users\josep\magic_classifier\postgres_utils.py:222: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
sentence = "create a correlation heatmap on titanic disaster" 
domain_class,domain_score,domain_confidence,domain_evidence = dtc.domain_classifier(sentence, True, True)
magic_class,magic_score,magic_confidence,magic_evidence = mg.magic_classifier(sentence, True, True)
magic_table = mg.find_magic_table_name(domain_class)  
print(f"\n#{idx}  {sentence} \n\nmagic class:{magic_class}  in domain:{domain_class}  finding table:{magic_table} \n\n")  
graph = mg.perform_magic(magic_class, magic_table)
# Out:
# #7  create a correlation heatmap on titanic disaster
#
# magic class:correlation heatmap  in domain:titanic  finding table:titanic
#
#
# ✅ Connection to PostgreSQL successful!
# ✅ Query executed successfully. Data retrieved.
# C:\Users\josep\magic_classifier\postgres_utils.py:222: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
sentence = "\correlation heatmap on wny health data" 
domain_class,domain_score,domain_confidence,domain_evidence = dtc.domain_classifier(sentence, True, True)
magic_class,magic_score,magic_confidence,magic_evidence = mg.magic_classifier(sentence, True, True)
magic_table = mg.find_magic_table_name(domain_class)  
print(f"\n#{idx}  {sentence} \n\nmagic class:{magic_class}  in domain:{domain_class}  finding table:{magic_table} \n\n")  
graph = mg.perform_magic(magic_class, magic_table)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\josep\AppData\Local\Temp\ipykernel_14084\1196845185.py:1: SyntaxWarning: invalid escape sequence '\c'
#   sentence = "\correlation heatmap on wny health data"
# C:\Users\josep\magic_classifier\postgres_utils.py:222: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# #7  \correlation heatmap on wny health data
#
# magic class:correlation heatmap  in domain:healthcare  finding table:wny_health
#
#
# ✅ Connection to PostgreSQL successful!
# ✅ Query executed successfully. Data retrieved.

# %%
magic_command = 'correlation heatmap'
table_name = 'wny_health'
graph = mg.perform_magic(magic_command, table_name)
# Out:
# ✅ Connection to PostgreSQL successful!
# ✅ Query executed successfully. Data retrieved.
# C:\Users\josep\magic_classifier\postgres_utils.py:222: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
magic_command = 'pair plot'
table_name = 'penguin'
graph = mg.perform_magic(magic_command, table_name)
# Out:
# ✅ Connection to PostgreSQL successful!
# ✅ Query executed successfully. Data retrieved.
# C:\Users\josep\magic_classifier\postgres_utils.py:222: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
magic_command = 'pair plot'
table_name = 'penguin'
# After running the function
graph = mg.perform_magic(magic_command, table_name)

# Explicitly show the plot (needed in Jupyter)
plt.show()
# Out:
# ✅ Connection to PostgreSQL successful!
# ✅ Query executed successfully. Data retrieved.
# C:\Users\josep\magic_classifier\postgres_utils.py:222: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
magic_command = 'correlation heatmap'
table_name = 'titanic'
graph = mg.perform_magic(magic_command, table_name)
# Out:
# ✅ Connection to PostgreSQL successful!
# ✅ Query executed successfully. Data retrieved.
# C:\Users\josep\magic_classifier\postgres_utils.py:222: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
magic_command = 'word cloud'
table_name = 'titanic'
graph = mg.perform_magic(magic_command, table_name)
# Out:
# ✅ Connection to PostgreSQL successful!
# ✅ Query executed successfully. Data retrieved.
# C:\Users\josep\magic_classifier\postgres_utils.py:222: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
magic_command = 'correlation heatmap'
table_name = 'penguin'
graph, insights = mg.perform_magic(magic_command, table_name)



definition = """
## The **correlation heatmap highlights** which clinical and demographic factors are most strongly connected in our population. 

## This helps identify both risk drivers and overlapping data, ensuring our analysis remains focused, accurate, and interpretable.
"""
sb.outmd(definition)
# Out:
# ✅ Connection to PostgreSQL successful!
# ✅ Query executed successfully. Data retrieved.
# C:\Users\josep\magic_classifier\postgres_utils.py:222: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 magic_command = 'correlation heatmap'
#       2 table_name = 'penguin'
# ----> 3 graph, insights = mg.perform_magic(magic_command, table_name)
#       7 definition = """
#       8 ## The **correlation heatmap highlights** which clinical and demographic factors are most strongly connected in our population.
#       9
#      10 ## This helps identify both risk drivers and overlapping data, ensuring our analysis remains focused, accurate, and interpretable.
#      11 """
#      12 sb.outmd(definition)
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
sentence = "\pair plot the penguins" 
domain_class,domain_score,domain_confidence,domain_evidence = dtc.domain_classifier(sentence, True, True)
magic_class,magic_score,magic_confidence,magic_evidence = mg.magic_classifier(sentence, True, True)
magic_table = mg.find_magic_table_name(domain_class)  
print(f"\n#{idx}  {sentence} \n\nmagic class:{magic_class}  in domain:{domain_class}  finding table:{magic_table} \n\n")  
graph = mg.perform_magic(magic_class, magic_table)

# %%
sentence = "\pair plot the titanic" 
domain_class,domain_score,domain_confidence,domain_evidence = dtc.domain_classifier(sentence, True, True)
magic_class,magic_score,magic_confidence,magic_evidence = mg.magic_classifier(sentence, True, True)
magic_table = mg.find_magic_table_name(domain_class)  
print(f"\n#{idx}  {sentence} \n\nmagic class:{magic_class}  in domain:{domain_class}  finding table:{magic_table} \n\n")  
graph = mg.perform_magic(magic_class, magic_table)

# %%
sentence = "\histogram wny health" 
domain_class,domain_score,domain_confidence,domain_evidence = dtc.domain_classifier(sentence, True, True)
magic_class,magic_score,magic_confidence,magic_evidence = mg.magic_classifier(sentence, True, True)
magic_table = mg.find_magic_table_name(domain_class)  
print(f"\n#{idx}  {sentence} \n\nmagic class:{magic_class}  in domain:{domain_class}  finding table:{magic_table} \n\n")  
graph = mg.perform_magic(magic_class, magic_table)

# %%
from pandas_profiling import ProfileReport
import ydata_profiling
ProfileReport(df_penguins).to_notebook_iframe()

# %%
sentence = "\pair plot the wny health data" 
domain_class,domain_score,domain_confidence,domain_evidence = dtc.domain_classifier(sentence, True, True)
magic_class,magic_score,magic_confidence,magic_evidence = mg.magic_classifier(sentence, True, True)
magic_table = mg.find_magic_table_name(domain_class)  
print(f"\n#{idx}  {sentence} \n\nmagic class:{magic_class}  in domain:{domain_class}  finding table:{magic_table} \n\n")  
graph = mg.perform_magic(magic_class, magic_table)

# %%
df_penguins = mg.magic_data_load('penguin')
df_penguins.shape

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot
ax = sns.countplot(x='species', data=df_penguins)

# Add counts above the bars
for p in ax.patches:
    count = int(p.get_height())
    ax.annotate(count,                     # Text to show
                (p.get_x() + p.get_width() / 2., count),  # x, y position
                ha='center', va='bottom',  # Align center/bottom
                fontsize=10)

plt.tight_layout()
plt.show()

# %%
sns.swarmplot(x='island', y='species', data=df_penguins)

# %%
sns.violinplot(x='island', y='species', data=df_penguins)

# %%
df_wny_health.select_dtypes('object').nunique().sort_values().plot(kind='barh')

# %%
definition ='''
## Magic architecture (MVC) 

1. **Identify Magic** - Automatically identifes major steps in notebook
2. **Load Data** - 1000 rows 95% accurate or  10000 rows 98.5% accurate or load whole table (100% accurate) 
3. **Perform Magic** - process Magic to produce nlp text or .png, or plot, or dataframe, or html 
4. **Render Magic Result** - render to produce .png, or plot, or html 
5. **Magic Controller** - special commands to work with magic results 
'''

sb.outmd(definition)

# %% [markdown]
# ## Step 0 - Process End - display log

# %%
# Calculate and classify the process performance 
status = ql.calculate_process_performance(solution_name, start_time) 
print(ql.append_log_file(solution_name))

# %% [markdown]
# #### https://github.com/JoeEberle/ -- josepheberle@outlook.com
